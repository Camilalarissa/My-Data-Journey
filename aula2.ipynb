# %% [markdown]
# <a href="https://colab.research.google.com/github/Camilalarissa/projetos-da-pos-graduacao/blob/main/aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introdução em Python

# %%
# Variaveis
# Interiro
idade = 45
#float
velocidade = 130.41
#boolena
ligado = 'true'


# operadores  aritimeticos + - * / %

print (velocidade)
velocidade += 10
print (velocidade)

vetor_idade = [30,12,60,75,10,56]
print (vetor_idade [1]);

# dicionario
dic_pessoal = {'nome' : 'Rodrigo', 'profisão' : 'professor', 'idade' : 38}
print (dic_pessoal ['nome'])
# Out:
# 130.41
# 140.41
# 12
# Rodrigo

# %%
if dic_pessoal ['idade'] > 40:
    print ( "professor acima de 40 anos ")
elif dic_pessoal ['idade'] > 30 and dic_pessoal ['idade'] < 20 :
    print ( "professor na media")

else:
    print( "professor abaixo de 40 anos" )
# Out:
# professor abaixo de 40 anos

# %%
dic_pessoal = [{'nome' : 'Rodrigo', 'profisão' : 'professor', 'idade' : 38},
               {'nome' : 'Tiago', 'profisão' : 'estudante', 'idade' : 7}]
for pessoa in dic_pessoal :
  print(pessoa['nome'])

for idade in vetor_idade :
 print(idade)
# Out:
# Rodrigo
# Tiago
# 30
# 12
# 60
# 75
# 10
# 56
